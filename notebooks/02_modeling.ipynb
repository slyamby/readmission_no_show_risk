# %%
import sys
sys.path.append("..")
from src.load_data import load_and_clean
from src.features import get_X_y_audit

df = load_and_clean("../data/raw/KaggleV2-May-2016.csv")
X, y, audit_df = get_X_y_audit(df)

print("Neighbourhood categories before/after grouping:",
      df["neighbourhood"].nunique(), "->", X["neighbourhood_grouped"].nunique())
print("\nX shape:", X.shape)
print("y distribution:\n", y.value_counts(normalize=True))
print("\ndtypes:\n", X.dtypes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 7
#       3 from src.load_data import load_and_clean
#       4 from src.features import get_X_y_audit
#       5
#       6 df = load_and_clean("../data/raw/KaggleV2-May-2016.csv")
# ----> 7 X, y, audit_df = get_X_y_audit(df)
#       8
#       9 print("Neighbourhood categories before/after grouping:",
#      10       df["neighbourhood"].nunique(), "->", X["neighbourhood_grouped"].nunique())
#
# File ~/projects/portfolio/readmission_no_show_risk/notebooks/../src/features.py:42, in get_X_y_audit(df)
#      40 """Returns (X, y, audit_df) - audit_df holds gender/scholarship, NOT used in training."""
#      41 df = build_features(df)
# ---> 42 X = df[FEATURE_COLS]
#      43 y = df["no_show_flag"]
#      44 audit_df = df[FAIRNESS_AUDIT_COLS]
#
# ...
